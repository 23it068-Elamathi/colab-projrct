# %% [markdown]
# <a href="https://colab.research.google.com/github/23it068-Elamathi/colab-projrct/blob/main/23IT068_Elamathi_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain langchain-community langchain-text-splitters
# !pip install sentence-transformers faiss-cpu chromadb
# !pip install groq pypdf pymupdf

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-507d9d16-b98a-44d4-a455-945ce45c7077" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-507d9d16-b98a-44d4-a455-945ce45c7077">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("Resume.pdf-7.pdf")
documents = loader.load()

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

recursive_splitter = RecursiveCharacterTextSplitter(
    chunk_size=200,
    chunk_overlap=20
)

recursive_docs = recursive_splitter.split_documents(documents)

# PRINT OUTPUT
for i, chunk in enumerate(recursive_docs[:10]):
    print(f"\n🔹 Recursive Chunk {i+1}:")
    print(chunk.page_content)
    print("-" * 50)

print("Total chunks:", len(recursive_docs))
# Out:
# 🔹 Recursive Chunk 1:
# Elamathi A
# Ui and ux designer
# elamathiathiannan@gmail.com • 11/1-44,kulalar street pudusampalli mettur.
# Summary
# --------------------------------------------------
#
# 🔹 Recursive Chunk 2:
# Summary
# Detail-oriented Business Administration student with foundational web development skills and a strong eagerness to
# --------------------------------------------------
#
# 🔹 Recursive Chunk 3:
# learn, seeking my first UI/UX Designer role. I am a responsible and orderly individual, ready to apply my communication
# --------------------------------------------------
#
# 🔹 Recursive Chunk 4:
# and learning agility to create user-friendly and aesthetically pleasing interfaces. I am excited to gain practical experience
# in a supportive, collaborative environment.
# Experience
# --------------------------------------------------
#
# 🔹 Recursive Chunk 5:
# Experience
# Intern Jan 2023 - Jan 2023
# Training Trains-web development
# ...

# %%
# !pip install faiss-cpu sentence-transformers

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS

# %%
embedding = HuggingFaceEmbeddings(
    model_name="all-MiniLM-L6-v2"
)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
vectorstore = FAISS.from_documents(
    recursive_docs,      # 👈 your chunks
    embedding
)

# %%
# For recursive
vectorstore = FAISS.from_documents(recursive_docs, embedding)

# %%
retriever = vectorstore.as_retriever()

# %%
vectorstore.save_local("resume_vector_db")

# %%
query = "What are the skills?"

docs = retriever.invoke(query)

for i, doc in enumerate(docs):
    print(f"\n🔹 Result {i+1}:")
    print(doc.page_content)
    print("-" * 50)
# Out:
# 🔹 Result 1:
# Skills
# Communication, Learning Agility, Web Development Basics, Text Processor, Slide Presentation,Hands-on experience
# in UI/UX design using Figma.
# Languages
# English, Tamil
# --------------------------------------------------
#
# 🔹 Result 2:
# and learning agility to create user-friendly and aesthetically pleasing interfaces. I am excited to gain practical experience
# in a supportive, collaborative environment.
# Experience
# --------------------------------------------------
#
# 🔹 Result 3:
# • Collaborated with peers on training exercises, fostering basic teamwork and problem-solving skills.
# Education
# College Jan 2023 - Present
# B.tech Information technology -Nandha Engineering College.
# --------------------------------------------------
#
# 🔹 Result 4:
# General Studies Jun 2022 - May 2023
# Higher Secondary (12th Grade) - Malco vidyalaya matric higher secondary school.
# Skills
# --------------------------------------------------

# %%
print("Total vectors stored:", len(vectorstore.index_to_docstore_id))
# Out:
# Total vectors stored: 9
